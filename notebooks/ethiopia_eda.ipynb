# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv("../data/ethiopia.csv")

# Show first 5 rows
print(df.head())

# %%
print("hello")

# %%
print("File loaded!")
print(df.shape)
